# %% [markdown]
# LAB 12:- ANALYSIS REPORT

# %% [markdown]
# Q. Make an analysis report from the mini project data.py, referring to Chapter 6.7 Notes, which was demonstrated in class using Streamlit. Run the program on your PC and write the workflow of the program along with the analysis report.

# %% [markdown]
# The given program follows a Data Pipeline Workflow.
#
#       Raw Data
#
#            ↓
#
#       Data Ingestion
#
#            ↓
#
#       Data Cleaning
#
#            ↓
#
#       Data Transformation
#
#            ↓
#
#       Data Analysis
#
#            ↓
#
#       Data Visualization
#
#            ↓
#
#       Dashboard Output

# %% [markdown]
# Detailed Workflow
#
# - Ingestion
#
#    - Load raw sales data into pandas DataFrame.
#
# - Cleaning
#
#   - Fill missing quantity with 1
#
#   - Remove negative quantity rows
#
#   - Convert date format
#
#   - Create new columns (total, month)
#
# - Transformation
#
#    - Group data by month
#
#    - Group data by product
#
#    - Group data by region
#
#    - Calculate revenue, units, transactions
#
# - Analysis
#
#    - Calculate KPIs
#
#    - Find best month, product, region
#
#    - Calculate average order value
#
# - Visualization
#
#    - Create charts using Plotly
#
#    - Show dashboard in Streamlit

# %% [markdown]
# # Analysis Report

# %% [markdown]
# End-to-End Data Pipeline

# %% [markdown]
# - OBJECTIVE
#
#    The objective of this experiment is to design and implement an end-to-end data pipeline that performs data ingestion, cleaning, transformation, analysis, and visualization using Python, Pandas, Streamlit, and Plotly.

# %% [markdown]
# - Tools and Technologies Used
#
#    - Python
#
#    - Pandas
#
#    - Streamlit
#
#    - Plotly
#
#    - Data Visualization
#
#    - Data Cleaning Techniques

# %% [markdown]
# - Description of the Pipeline
#
#    The data pipeline consists of five main stages:
#
#    - Data Ingestion – Raw sales data is loaded into the system.
#
#    - Data Cleaning – Missing values are handled and incorrect data is removed.
#
#    - Data Transformation – Data is aggregated into monthly, product-wise, and region-wise summaries.
#
#    - Data Analysis – Key Performance Indicators (KPIs) are calculated.
#
#    - Data Visualization – Charts and dashboards are created for better understanding.

# %% [markdown]
# - Data Cleaning Performed
#
#   - Missing quantity values were replaced with 1.
#
#   - Rows with negative quantity were removed.
#
#   - Total revenue column was calculated.
#
#   - Month column was extracted from date.

# %% [markdown]
# - KPIs Calculated
#
#   - Total Revenue
#
#   - Total Units Sold
#
#   - Total Transactions
#
#   - Average Order Value
#
#   - Best Performing Month
#
#   - Best Selling Product
#
#   - Best Region

# %% [markdown]
# - Visualization
#
#    The following charts were generated:
#
#      - Monthly Revenue Trend (Line Chart)
#
#      - Units Sold per Month (Bar Chart)
#
#      - Transactions per Month (Bar Chart)
#
#      - Revenue by Product (Pie Chart)
#
#     - Revenue by Region (Pie Chart)
#
#     - Revenue by Product per Month (Grouped Bar Chart)

# %% [markdown]
# - Conclusion
#
#     The end-to-end data pipeline successfully demonstrates the complete data processing workflow from raw data ingestion to visualization. The pipeline helps in identifying business insights such as best performing product, region, and month. Streamlit provides an interactive interface for exploring each stage of the pipeline.This experiment successfully implemented an end-to-end data pipeline using Python. The pipeline included data ingestion, cleaning, transformation, analysis, and visualization. The Streamlit dashboard displayed KPIs and charts that helped analyze sales performance by month, product, and region. The project demonstrates how raw data can be converted into meaningful insights using data processing and visualization tools.
